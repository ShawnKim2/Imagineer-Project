# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 라이브러리 불러오기
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.preprocessing import image
from tensorflow.keras.callbacks import EarlyStopping

# 데이터 경로 설정
data_dir = '/content/drive/MyDrive/smart_agriculture/tomato_3000_v2/train'

# 클래스 이름 확인
class_names = os.listdir(data_dir)
class_names = [cls for cls in class_names if not cls.startswith('.')]
class_names.sort()  # 항상 고정 순서로 정렬
print("클래스 목록:", class_names)

# 이미지 경로 및 라벨 수집
image_paths = []
labels = []

for class_name in class_names:
    class_path = os.path.join(data_dir, class_name)
    file_names = os.listdir(class_path)
    file_names = [f for f in file_names if not f.startswith('.')]  # 숨김파일 제외
    for file_name in file_names:
        image_paths.append(os.path.join(class_path, file_name))
        labels.append(class_name)

# numpy array로 변환
image_paths = np.array(image_paths)
labels = np.array(labels)

# 데이터셋 분할 (Train+Val:Test = 90:10 → Train:Val:Test = 72:18:10) 42: 은하수를 여행하는 히치하이커를 위한 안내서
trainval_paths, test_paths, trainval_labels, test_labels = train_test_split(
    image_paths, labels, test_size=0.1, stratify=labels, random_state=42
)

train_paths, val_paths, train_labels, val_labels = train_test_split(
    trainval_paths, trainval_labels, test_size=0.2, stratify=trainval_labels, random_state=42
)

print(f"Train: {len(train_paths)}, Validation: {len(val_paths)}, Test: {len(test_paths)}")

# 데이터프레임 생성
train_df = pd.DataFrame({'filename': train_paths, 'class': train_labels})
val_df = pd.DataFrame({'filename': val_paths, 'class': val_labels})
test_df = pd.DataFrame({'filename': test_paths, 'class': test_labels})

# class_indices 생성 (항상 고정 순서)
class_indices = {cls: i for i, cls in enumerate(class_names)}
print("Class Indices:", class_indices)

# 이미지 제너레이터 설정
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.2,
    horizontal_flip=True
)

val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

# 제너레이터 생성
train_gen = train_datagen.flow_from_dataframe(
    train_df,
    x_col='filename',
    y_col='class',
    target_size=(100, 100),
    batch_size=32,
    class_mode='categorical',
    classes=class_indices,
    shuffle=True
)

val_gen = val_datagen.flow_from_dataframe(
    val_df,
    x_col='filename',
    y_col='class',
    target_size=(100, 100),
    batch_size=32,
    class_mode='categorical',
    classes=class_indices,
    shuffle=True
)

test_gen = test_datagen.flow_from_dataframe(
    test_df,
    x_col='filename',
    y_col='class',
    target_size=(100, 100),
    batch_size=32,
    class_mode='categorical',
    classes=class_indices,
    shuffle=False
)

# CNN 모델 정의
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(100, 100, 3)),
    MaxPooling2D(2),
    Conv2D(64, (3, 3), activation='relu', padding='same'),
    MaxPooling2D(2),
    Conv2D(128, (3, 3), activation='relu', padding='same'),
    MaxPooling2D(2),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(len(class_names), activation='softmax')
])

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model.summary()

# EarlyStopping 설정
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True
)

# 모델 학습
history = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=30,
    callbacks=[early_stop]
)

# 학습 결과 시각화
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Training and Validation Accuracy')
plt.grid()
plt.show()

# 최종 테스트 성능 평가
test_loss, test_acc = model.evaluate(test_gen)
print(f"최종 Test Accuracy: {test_acc:.4f} / 최종 Test Loss: {test_loss:.4f}")

# 예측 함수 (개별 이미지 분류)
def predict_ripe_class(model, img_path):
    img = image.load_img(img_path, target_size=(100, 100))
    img_array = image.img_to_array(img) / 255.0
    img_array = np.expand_dims(img_array, axis=0)

    predictions = model.predict(img_array)
    class_idx = np.argmax(predictions[0])
    class_labels = class_names  # 자동으로 클래스명 사용
    return class_labels[class_idx], predictions[0]
# Out:
# 클래스 목록: ['0- Ripe 100- Unripe', '100- Ripe 0- Unripe', '30- Ripe 70- Unripe', '50- Ripe 50- Unripe', '70- Ripe 30- Unripe']
# Train: 2341, Validation: 586, Test: 326
# Class Indices: {'0- Ripe 100- Unripe': 0, '100- Ripe 0- Unripe': 1, '30- Ripe 70- Unripe': 2, '50- Ripe 50- Unripe': 3, '70- Ripe 30- Unripe': 4}
# Found 2341 validated image filenames belonging to 5 classes.
# Found 586 validated image filenames belonging to 5 classes.
# Found 326 validated image filenames belonging to 5 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 100, 100, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 50, 50, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 50, 50, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 25, 25, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 25, 25, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 12, 12, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 18432)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │     2,359,424 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 5)              │           645 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,453,317 (9.36 MB)
#  Trainable params: 2,453,317 (9.36 MB)
#  Non-trainable params: 0 (0.00 B)
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1695s 23s/step - accuracy: 0.4623 - loss: 1.2157 - val_accuracy: 0.7150 - val_loss: 0.7486
# Epoch 2/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 194ms/step - accuracy: 0.6432 - loss: 0.8027 - val_accuracy: 0.7645 - val_loss: 0.5324
# Epoch 3/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 193ms/step - accuracy: 0.7262 - loss: 0.6163 - val_accuracy: 0.7560 - val_loss: 0.5444
# Epoch 4/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 209ms/step - accuracy: 0.7230 - loss: 0.6151 - val_accuracy: 0.7816 - val_loss: 0.4997
# Epoch 5/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 196ms/step - accuracy: 0.7436 - loss: 0.6047 - val_accuracy: 0.7747 - val_loss: 0.4843
# Epoch 6/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 193ms/step - accuracy: 0.7737 - loss: 0.5295 - val_accuracy: 0.7747 - val_loss: 0.5040
# Epoch 7/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 194ms/step - accuracy: 0.7763 - loss: 0.5208 - val_accuracy: 0.7969 - val_loss: 0.4318
# Epoch 8/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 196ms/step - accuracy: 0.7717 - loss: 0.5565 - val_accuracy: 0.7765 - val_loss: 0.4701
# Epoch 9/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 197ms/step - accuracy: 0.8055 - loss: 0.4732 - val_accuracy: 0.7474 - val_loss: 0.5188
# Epoch 10/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 196ms/step - accuracy: 0.7880 - loss: 0.5127 - val_accuracy: 0.8225 - val_loss: 0.4151
# Epoch 11/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 196ms/step - accuracy: 0.8135 - loss: 0.4814 - val_accuracy: 0.7867 - val_loss: 0.4735
# Epoch 12/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 197ms/step - accuracy: 0.8064 - loss: 0.4694 - val_accuracy: 0.8055 - val_loss: 0.4239
# Epoch 13/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 200ms/step - accuracy: 0.7884 - loss: 0.4968 - val_accuracy: 0.8038 - val_loss: 0.4268
# Epoch 14/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 20s 195ms/step - accuracy: 0.8102 - loss: 0.4474 - val_accuracy: 0.8259 - val_loss: 0.4091
# Epoch 15/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 207ms/step - accuracy: 0.8066 - loss: 0.4364 - val_accuracy: 0.7901 - val_loss: 0.4914
# Epoch 16/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 14s 194ms/step - accuracy: 0.8047 - loss: 0.4603 - val_accuracy: 0.7662 - val_loss: 0.4815
# Epoch 17/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 211ms/step - accuracy: 0.8053 - loss: 0.4755 - val_accuracy: 0.7167 - val_loss: 0.6153
# Epoch 18/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 15s 195ms/step - accuracy: 0.7876 - loss: 0.4645 - val_accuracy: 0.7986 - val_loss: 0.4587
# Epoch 19/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 20s 193ms/step - accuracy: 0.8254 - loss: 0.4163 - val_accuracy: 0.7338 - val_loss: 0.6086
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 153s 15s/step - accuracy: 0.8278 - loss: 0.4678
# 최종 Test Accuracy: 0.8558
